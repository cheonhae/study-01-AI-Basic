# %% [markdown]
# # 사이킷런 내장 데이터셋 연습 - iris data

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.3.2'

# %%
#!pip install -U scikit-learn

# %%
from sklearn import datasets

# %%
# 사이킷런의 내장 데이터셋 리스트

# %%
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_arff_parser',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
# ...

# %%
# 아이리스 데이터 소개

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 데이터 수집

# %%
#sklearn의 toy dataset import

# %% [markdown]
# ### 데이터 탐색

# %%
# iris type 확인

# %%
#데이터셋 설명

# %%
# 특성 데이터 확인

# %%
#특성의 이름 확인

# %%
# 타겟 데이터 확인

# %%
# 타겟(레이블, 클래스)의 이름 확인

# %%
# 레코드(샘플)의 수 확인

# %%
# data 일부 확인
# 앞에서부터 5개

# %%
#pandas DataFrame으로 데이터 확인

# %% [markdown]
# ### 학습용/검증용 데이터 분리

# %%
# train set, test set으로 분리
#import sklearn.model_selection as ms

# %% [markdown]
# ### 모델 구축

# %%
# 1) 분석을 수행하기 위한 추정자(estimator) 생성
# 2) 학습 수행: 생성된 객체에 대해 fit() 메소드 수행
# 3) 예측 결과 도출: 생성된 객체 또는 학습이 수행된 분석 결과에 대해 predict()메소드 수행

# %%
# 1) 분석을 수행하기 위한 추정자(estimator) 생성


# 2) 학습 수행 : 생성된 객체에 대해 fit() 메소드 수행


# 3) 예측 결과 수행

# %% [markdown]
# ### 모델 평가

# %%
# 생성된 객체 또는 학습이 수행된 분석 결과에 대해 적합한 성능 평가 지표 도출
# from sklearn.metrics import ****
